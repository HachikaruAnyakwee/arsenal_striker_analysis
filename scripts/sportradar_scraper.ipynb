# %%
import requests
import json
import time
import os
from dotenv import load_dotenv
import pandas as pd
# Out:
# /Users/hachikaruanyakwee/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#Load API key
load_dotenv()
API_KEY = os.getenv("SPORTRADAR_API_KEY")

# %%
#Base URL for Sportradar API (adjust for trial/production)
BASE_URL = "https://api.sportradar.com/soccer/trial/v4/en"

# %%
#Premier League Competition ID
PREMIER_LEAGUE_ID = "sr:competition:17"

# %%
#Data directory
DATA_DIR = "data"
RAW_DATA_DIR = os.path.join("..", DATA_DIR, "raw")

if not os.path.exists(DATA_DIR):
    os.makedirs(DATA_DIR)
if not os.path.exists(RAW_DATA_DIR):
    os.makedirs(RAW_DATA_DIR)

# %%
#Function to fetch the latest epl season
def get_latest_season():
    url = f"{BASE_URL}/competitions/{PREMIER_LEAGUE_ID}/seasons.json?api_key={API_KEY}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        latest_season = data['seasons'][-1]  # Get most recent season
        print(f"✅ Latest Season: {latest_season['name']} (ID: {latest_season['id']})")
        return latest_season['id']
    else:
        print(f"❌ Failed to fetch season: {response.status_code}")
        return None

# %%
#Function to fetch Arsenal's team ID
def get_teams(season_id):
    time.sleep(10)
    url = f"{BASE_URL}/seasons/{season_id}/competitors.json?api_key={API_KEY}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("Raw JSON Response:")
        print(json.dumps(data, indent=4))  # Print nicely formatted JSON
        teams = data.get("season_competitors")  # Use the correct key
        if teams:
            team_data = []
            for team in teams:
                print(f"✅ Team: {team['name']} (ID: {team['id']})")
                team_data.append(team)
                if "Arsenal" in team["name"]:
                    arsenal_id = team['id']
            df = pd.DataFrame(team_data)
            df.to_csv(os.path.join(RAW_DATA_DIR, "teams.csv"), index=False)  # Save to CSV in data dir
            return arsenal_id
        else:
            print("❌ Key 'season_competitors' not found in the response.")
            return None
    else:
        print(f"❌ Failed to fetch teams: {response.status_code}")
        return None

# %%
#Function to fetch player statistics for Arsenal
def get_arsenal_players(team_id):
    time.sleep(10)
    url = f"{BASE_URL}/competitors/{team_id}/profile.json?api_key={API_KEY}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        players = data["players"]

        print(f"✅ Arsenal Squad ({len(players)} players):")
        player_data = []
        for player in players:
            print(f"  - {player['name']} (ID: {player['id']})")
            player_data.append(player)
        df = pd.DataFrame(player_data)
        df.to_csv(os.path.join(RAW_DATA_DIR, "arsenal_players.csv"), index=False)  # Save to CSV
        return players
    else:
        print(f"❌ Failed to fetch Arsenal squad: {response.status_code}")
        return None

# %%
#Function to fetch match schedule for Arsenal
def get_arsenal_schedule(team_id):
    time.sleep(10)
    url = f"{BASE_URL}/competitors/{team_id}/schedules.json?api_key={API_KEY}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print("\nRaw JSON Response (Arsenal Schedule):")
        print(json.dumps(data, indent=4))  # Print nicely formatted JSON
        schedules = data.get("schedules")  # Get the 'schedules' list
        if schedules:
            matches = [schedule["sport_event"] for schedule in schedules]  # Extract 'sport_event' from each schedule
            print(f"✅ Arsenal Matches ({len(matches)} games):")
            match_data = []
            for match in matches[:5]:  # Show first 5 matches
                print(
                    f"  - {match['start_time']} | {match['competitors'][0]['name']} vs {match['competitors'][1]['name']}")
                match_data.append(match)
            df = pd.DataFrame(matches)
            df.to_csv(os.path.join(RAW_DATA_DIR, "arsenal_schedule.csv"), index=False)  # Save to CSV
            return matches
        else:
            print("❌ Key 'schedules' not found in the response.")
            return None
    else:
        print(f"❌ Failed to fetch Arsenal schedule: {response.status_code}")
        return None

# %%
#Function to fetch Arsenal palayer statistics
def get_arsenal_stats(season_id, team_id):
    time.sleep(10)
    url = f"{BASE_URL}/seasons/{season_id}/competitors/{team_id}/statistics.json?api_key={API_KEY}"
    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()
        print(f"✅ Arsenal Stats Retrieved Successfully")
        df = pd.DataFrame(data)
        df.to_csv(os.path.join(RAW_DATA_DIR, "arsenal_stats.csv"), index=False)  # Save to CSV
        return data
    else:
        print(f"❌ Failed to fetch Arsenal statistics: {response.status_code}")
        return None

# %%
#Main function for data collection
def main():
    print("🔄 Fetching latest Premier League season...")
    season_id = get_latest_season()
    if not season_id:
        return

    print("\n🔄 Fetching Premier League teams...")
    arsenal_id = get_teams(season_id)
    if not arsenal_id:
        return

    print("\n🔄 Fetching Arsenal squad...")
    get_arsenal_players(arsenal_id)

    print("\n🔄 Fetching Arsenal schedule...")
    get_arsenal_schedule(arsenal_id)

    print("\n🔄 Fetching Arsenal statistics...")
    get_arsenal_stats(season_id, arsenal_id)

if __name__ == "__main__":
    main()
# Out:
# 🔄 Fetching latest Premier League season...
# ✅ Latest Season: Premier League 24/25 (ID: sr:season:118689)
#
# 🔄 Fetching Premier League teams...
# Raw JSON Response:
# {
#     "generated_at": "2025-03-27T17:54:12+00:00",
#     "season_competitors": [
#         {
#             "id": "sr:competitor:3",
#             "name": "Wolverhampton Wanderers",
#             "short_name": "Wolverhampton",
#             "abbreviation": "WOL",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:7",
#             "name": "Crystal Palace",
#             "short_name": "Crystal Palace",
#             "abbreviation": "CRY",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:14",
#             "name": "Nottingham Forest",
#             "short_name": "Nottingham",
#             "abbreviation": "NFO",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:17",
#             "name": "Manchester City",
#             "short_name": "Man City",
#             "abbreviation": "MCI",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:30",
#             "name": "Brighton & Hove Albion",
#             "short_name": "Brighton",
#             "abbreviation": "BRI",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:31",
#             "name": "Leicester City",
#             "short_name": "Leicester",
#             "abbreviation": "LEI",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:32",
#             "name": "Ipswich Town",
#             "short_name": "Ipswich",
#             "abbreviation": "IPS",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:33",
#             "name": "Tottenham Hotspur",
#             "short_name": "Tottenham",
#             "abbreviation": "TOT",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:35",
#             "name": "Manchester United",
#             "short_name": "Man Utd",
#             "abbreviation": "MUN",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:37",
#             "name": "West Ham United",
#             "short_name": "West Ham",
#             "abbreviation": "WHU",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:38",
#             "name": "Chelsea FC",
#             "short_name": "Chelsea",
#             "abbreviation": "CHE",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:39",
#             "name": "Newcastle United",
#             "short_name": "Newcastle",
#             "abbreviation": "NEW",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:40",
#             "name": "Aston Villa",
#             "short_name": "Aston Villa",
#             "abbreviation": "AVL",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:42",
#             "name": "Arsenal FC",
#             "short_name": "Arsenal",
#             "abbreviation": "ARS",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:43",
#             "name": "Fulham FC",
#             "short_name": "Fulham",
#             "abbreviation": "FUL",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:44",
#             "name": "Liverpool FC",
#             "short_name": "Liverpool",
#             "abbreviation": "LFC",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:45",
#             "name": "Southampton FC",
#             "short_name": "Southampton",
#             "abbreviation": "SOU",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:48",
#             "name": "Everton FC",
#             "short_name": "Everton",
#             "abbreviation": "EVE",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:50",
#             "name": "Brentford FC",
#             "short_name": "Brentford",
#             "abbreviation": "BRE",
#             "gender": "male"
#         },
#         {
#             "id": "sr:competitor:60",
#             "name": "AFC Bournemouth",
#             "short_name": "Bournemouth",
#             "abbreviation": "BOU",
#             "gender": "male"
#         }
#     ]
# }
# ✅ Team: Wolverhampton Wanderers (ID: sr:competitor:3)
# ✅ Team: Crystal Palace (ID: sr:competitor:7)
# ✅ Team: Nottingham Forest (ID: sr:competitor:14)
# ✅ Team: Manchester City (ID: sr:competitor:17)
# ✅ Team: Brighton & Hove Albion (ID: sr:competitor:30)
# ✅ Team: Leicester City (ID: sr:competitor:31)
# ✅ Team: Ipswich Town (ID: sr:competitor:32)
# ✅ Team: Tottenham Hotspur (ID: sr:competitor:33)
# ✅ Team: Manchester United (ID: sr:competitor:35)
# ✅ Team: West Ham United (ID: sr:competitor:37)
# ✅ Team: Chelsea FC (ID: sr:competitor:38)
# ✅ Team: Newcastle United (ID: sr:competitor:39)
# ✅ Team: Aston Villa (ID: sr:competitor:40)
# ✅ Team: Arsenal FC (ID: sr:competitor:42)
# ✅ Team: Fulham FC (ID: sr:competitor:43)
# ✅ Team: Liverpool FC (ID: sr:competitor:44)
# ✅ Team: Southampton FC (ID: sr:competitor:45)
# ✅ Team: Everton FC (ID: sr:competitor:48)
# ✅ Team: Brentford FC (ID: sr:competitor:50)
# ✅ Team: AFC Bournemouth (ID: sr:competitor:60)
#
# 🔄 Fetching Arsenal squad...
# ✅ Arsenal Squad (32 players):
#   - Neto (ID: sr:player:84844)
#   - Jorginho (ID: sr:player:132874)
#   - Trossard, Leandro (ID: sr:player:135666)
#   - Sterling, Raheem (ID: sr:player:138534)
#   - Zinchenko, Oleksandr (ID: sr:player:287643)
#   - Partey, Thomas (ID: sr:player:316148)
#   - Tierney, Kieran (ID: sr:player:366592)
#   - Odegaard, Martin (ID: sr:player:547410)
#   - Raya, David (ID: sr:player:581310)
#   - Merino, Mikel (ID: sr:player:592010)
#   - Tomiyasu, Takehiro (ID: sr:player:772819)
#   - Jesus, Gabriel (ID: sr:player:835751)
#   - Rice, Declan (ID: sr:player:934552)
#   - Havertz, Kai (ID: sr:player:937210)
#   - White, Ben (ID: sr:player:1015179)
#   - Timber, Jurrien (ID: sr:player:1059325)
#   - Kiwior, Jakub (ID: sr:player:1091644)
#   - Magalhaes, Gabriel (ID: sr:player:1099395)
#   - Calafiori, Riccardo (ID: sr:player:1297524)
#   - Saka, Bukayo (ID: sr:player:1479630)
#   - Saliba, William (ID: sr:player:1513599)
#   - Martinelli, Gabriel (ID: sr:player:1663313)
#   - Oulad M Hand, Salah Eddine (ID: sr:player:2244495)
#   - Setford, Tommy (ID: sr:player:2268223)
#   - Nwaneri, Ethan (ID: sr:player:2447727)
#   - Butler-Oyedeji, Nathan (ID: sr:player:2506009)
#   - Lewis-Skelly, Myles (ID: sr:player:2518835)
#   - Rojas, Alexei (ID: sr:player:2605855)
#   - Nichols, Joshua (ID: sr:player:2691828)
#   - Gower, Jimi (ID: sr:player:2711838)
#   - Kabia, Ismeal (ID: sr:player:2758543)
#   - Porter, Jack (ID: sr:player:2863029)
#
# 🔄 Fetching Arsenal schedule...
#
# Raw JSON Response (Arsenal Schedule):
# {
#     "generated_at": "2025-03-27T17:54:34+00:00",
#     "schedules": [
#         {
#             "sport_event": {
#                 "id": "sr:sport_event:50850537",
#                 "start_time": "2025-03-16T13:30:00+00:00",
#                 "start_time_confirmed": true,
#                 "sport_event_context": {
#                     "sport": {
#                         "id": "sr:sport:1",
#                         "name": "Soccer"
#                     },
#                     "category": {
#                         "id": "sr:category:1",
#                         "name": "England",
#                         "country_code": "ENG"
#                     },
#                     "competition": {
#                         "id": "sr:competition:17",
#                         "name": "Premier League",
#                         "gender": "men"
#                     },
#                     "season": {
#                         "id": "sr:season:118689",
#                         "name": "Premier League 24/25",
#                         "start_date": "2024-08-16",
#                         "end_date": "2025-05-25",
#                         "year": "24/25",
#                         "competition_id": "sr:competition:17"
#                     },
#                     "stage": {
#                         "order": 1,
#                         "type": "league",
#                         "phase": "regular season",
#                         "start_date": "2024-08-16",
#                         "end_date": "2025-05-25",
#                         "year": "24/25"
#                     },
#                     "round": {
#                         "number": 29
#                     },
#                     "groups": [
#                         {
#                             "id": "sr:league:84075",
#                             "name": "Premier League 24/25"
#                         }
#                     ]
#                 },
#                 "coverage": {
#                     "type": "sport_event",
#                     "sport_event_properties": {
#                         "lineups": true,
#                         "formations": false,
#                         "venue": true,
#                         "extended_player_stats": true,
#                         "extended_team_stats": true,
#                         "lineups_availability": "pre",
#                         "ballspotting": true,
#                         "commentary": true,
#                         "fun_facts": true,
#                         "goal_scorers": true,
#                         "goal_scorers_live": true,
#                         "scores": "live",
#                         "game_clock": true,
#                         "deeper_play_by_play": true,
#                         "deeper_player_stats": true,
#                         "deeper_team_stats": true,
#                         "basic_play_by_play": true,
#                         "basic_player_stats": true,
#                         "basic_team_stats": true
#                     }
#                 },
#                 "competitors": [
#                     {
#                         "id": "sr:competitor:42",
#                         "name": "Arsenal FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "ARS",
#                         "qualifier": "home",
#                         "gender": "male"
#                     },
#                     {
#                         "id": "sr:competitor:38",
#                         "name": "Chelsea FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "CHE",
#                         "qualifier": "away",
#                         "gender": "male"
#                     }
#                 ],
#                 "venue": {
#                     "id": "sr:venue:624",
#                     "name": "Emirates Stadium",
#                     "capacity": 60704,
#                     "city_name": "London",
#                     "country_name": "England",
#                     "map_coordinates": "51.555050,-0.108046",
#                     "country_code": "ENG",
#                     "timezone": "Europe/London"
#                 },
#                 "channels": [
#                     {
#                         "name": "V Sport Football HD SE - Thor 2/3 (1.0W)",
#                         "url": "https://www.allente.se/tv-guide/",
#                         "country": "Sweden",
#                         "country_code": "SWE"
#                     },
#                     {
#                         "name": "Sky Sport Uno HD - Hot Bird 1/2/3/4/6 (13.0E)",
#                         "url": "https://guidatv.sky.it/sport-e-calcio?vista=griglia",
#                         "country": "Italy",
#                         "country_code": "ITA"
#                     },
#                     {
#                         "name": "Bein Sports HD 3 TR - T\u00fcrksat 1C / Eurasiasat 1 (42.0E)",
#                         "url": "http://tr.beinsports.com/yayin-akisi/beinsports-3",
#                         "country": "Turkey",
#                         "country_code": "TUR"
#                     },
#                     {
#                         "name": "Digi Sport 1 RO - Thor 2/3 (1.0W)",
#                         "url": "http://www.digisport.ro/Program/",
#                         "country": "Romania",
#                         "country_code": "ROU"
#                     },
#                     {
#                         "name": "CANAL+ FR - Astra 1C-1H / 2C (19.2E)",
#                         "url": "https://www.canalplus.com/programme-tv/",
#                         "country": "France",
#                         "country_code": "FRA"
#                     },
#                     {
#                         "name": "Spiler 1 TV - Thor 2/3 (1.0W)",
#                         "url": "http://spilertv.hu/musorujsag/",
#                         "country": "Hungary",
#                         "country_code": "HUN"
#                     },
#                     {
#                         "name": "Spiler 1 TV - Thor 2/3 (1.0W)",
#                         "url": "http://spilertv.hu/musorujsag/",
#                         "country": "Romania",
#                         "country_code": "ROU"
#                     },
#                     {
#                         "name": "Peacock Premium",
#                         "country": "United States",
#                         "country_code": "USA"
#                     },
#                     {
#                         "name": "Sky Sport Premier League HD - Astra 1C-1H / 2C (19.2E)",
#                         "url": "https://info.sky.de/inhalt/de/programm_info_live_events_start.jsp",
#                         "country": "Germany",
#                         "country_code": "DEU"
#                     }
#                 ],
#                 "sport_event_conditions": {
#                     "referees": [
#                         {
#                             "id": "sr:referee:107059",
#                             "name": "Kavanagh, Christopher",
#                             "nationality": "England",
#                             "country_code": "ENG",
#                             "type": "main_referee"
#                         },
#                         {
#                             "id": "sr:referee:74292",
#                             "name": "Betts, Lee",
#                             "nationality": "England",
#                             "country_code": "ENG",
#                             "type": "first_assistant_referee"
#                         },
#                         {
#                             "id": "sr:referee:978141",
#                             "name": "Mainwaring, James",
#                             "nationality": "England",
#                             "country_code": "ENG",
#                             "type": "second_assistant_referee"
#                         },
#                         {
#                             "id": "sr:referee:1972503",
#                             "name": "Barrott, Samuel",
#                             "nationality": "England",
#                             "country_code": "ENG",
#                             "type": "fourth_official"
#                         },
#                         {
#                             "id": "sr:referee:138289",
#                             "name": "Gillett, Jarred",
#                             "nationality": "Australia",
#                             "country_code": "AUS",
#                             "type": "video_assistant_referee"
#                         }
#                     ],
#                     "attendance": {
#                         "count": 60311
#                     },
#                     "weather": {
#                         "pitch_conditions": "good",
#                         "overall_conditions": "good"
#                     },
#                     "ground": {
#                         "neutral": false
#                     },
#                     "lineups": {
#                         "confirmed": true
#                     }
#                 }
#             },
#             "sport_event_status": {
#                 "status": "closed",
#                 "match_status": "ended",
#                 "home_score": 1,
#                 "away_score": 0,
#                 "winner_id": "sr:competitor:42",
#                 "period_scores": [
#                     {
#                         "home_score": 1,
#                         "away_score": 0,
#                         "type": "regular_period",
#                         "number": 1
#                     },
#                     {
#                         "home_score": 0,
#                         "away_score": 0,
#                         "type": "regular_period",
#                         "number": 2
#                     }
#                 ],
#                 "ball_locations": [
#                     {
#                         "order": 4,
#                         "x": 10,
#                         "y": 54,
#                         "qualifier": "home"
#                     },
#                     {
#                         "order": 3,
#                         "x": 8,
#                         "y": 51,
#                         "qualifier": "home"
#                     },
#                     {
#                         "order": 2,
#                         "x": 8,
#                         "y": 51,
#                         "qualifier": "away"
#                     },
#                     {
#                         "order": 1,
#                         "x": 11,
#                         "y": 78,
#                         "qualifier": "away"
#                     }
#                 ],
#                 "match_situation": {
#                     "status": "safe",
#                     "qualifier": "home",
#                     "updated_at": "2025-03-16T15:22:54+00:00"
#                 }
#             }
#         },
#         {
#             "sport_event": {
#                 "id": "sr:sport_event:58261997",
#                 "start_time": "2025-03-12T20:00:00+00:00",
#                 "start_time_confirmed": true,
#                 "sport_event_context": {
#                     "sport": {
#                         "id": "sr:sport:1",
#                         "name": "Soccer"
#                     },
#                     "category": {
#                         "id": "sr:category:393",
#                         "name": "International Clubs"
#                     },
#                     "competition": {
#                         "id": "sr:competition:7",
#                         "name": "UEFA Champions League",
#                         "gender": "men"
#                     },
#                     "season": {
#                         "id": "sr:season:119239",
#                         "name": "UEFA Champions League 24/25",
#                         "start_date": "2024-07-09",
#                         "end_date": "2025-05-31",
#                         "year": "24/25",
#                         "competition_id": "sr:competition:7"
#                     },
#                     "stage": {
#                         "order": 4,
#                         "type": "cup",
#                         "phase": "playoffs",
#                         "start_date": "2025-02-11",
#                         "end_date": "2025-05-31",
#                         "year": "24/25"
#                     },
#                     "round": {
#                         "name": "round_of_16",
#                         "other_sport_event_id": "sr:sport_event:58261999",
#                         "cup_round_sport_event_number": 2,
#                         "cup_round_number_of_sport_events": 2,
#                         "cup_round_id": "sr:cup_round:2319081"
#                     },
#                     "groups": [
#                         {
#                             "id": "sr:cup:166619",
#                             "name": "UEFA Champions League 24/25, Knockout stage"
#                         }
#                     ]
#                 },
#                 "coverage": {
#                     "type": "sport_event",
#                     "sport_event_properties": {
#                         "lineups": true,
#                         "formations": false,
#                         "venue": true,
#                         "extended_player_stats": true,
#                         "extended_team_stats": true,
#                         "lineups_availability": "pre",
#                         "ballspotting": true,
#                         "commentary": true,
#                         "fun_facts": true,
#                         "goal_scorers": true,
#                         "goal_scorers_live": true,
#                         "scores": "live",
#                         "game_clock": true,
#                         "deeper_play_by_play": true,
#                         "deeper_player_stats": true,
#                         "deeper_team_stats": true,
#                         "basic_play_by_play": true,
#                         "basic_player_stats": true,
#                         "basic_team_stats": true
#                     }
#                 },
#                 "competitors": [
#                     {
#                         "id": "sr:competitor:42",
#                         "name": "Arsenal FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "ARS",
#                         "qualifier": "home",
#                         "gender": "male"
#                     },
#                     {
#                         "id": "sr:competitor:2952",
#                         "name": "PSV Eindhoven",
#                         "country": "Netherlands",
#                         "country_code": "NLD",
#                         "abbreviation": "PSV",
#                         "qualifier": "away",
#                         "gender": "male"
#                     }
#                 ],
#                 "venue": {
#                     "id": "sr:venue:624",
#                     "name": "Emirates Stadium",
#                     "capacity": 60704,
#                     "city_name": "London",
#                     "country_name": "England",
#                     "map_coordinates": "51.555050,-0.108046",
#                     "country_code": "ENG",
#                     "timezone": "Europe/London"
#                 },
#                 "channels": [
#                     {
#                         "name": "SRF zwei HD - Hot Bird 1/2/3/4/6 (13.0E)",
#                         "url": "http://tvprogramm.srf.ch/",
#                         "country": "Switzerland",
#                         "country_code": "CHE"
#                     },
#                     {
#                         "name": "SKY Sport 252 HD - Hot Bird 1/2/3/4/6 (13.0E)",
#                         "url": "https://guidatv.sky.it/sport-e-calcio?vista=griglia",
#                         "country": "Italy",
#                         "country_code": "ITA"
#                     },
#                     {
#                         "name": "Sport2 HU - Thor 2/3 (1.0W)",
#                         "url": "http://www.sport1tv.hu/tv-musor/",
#                         "country": "Hungary",
#                         "country_code": "HUN"
#                     },
#                     {
#                         "name": "Sport2 HU - Thor 2/3 (1.0W)",
#                         "url": "http://www.sport1tv.hu/tv-musor/",
#                         "country": "Romania",
#                         "country_code": "ROU"
#                     },
#                     {
#                         "name": "MTV Urheilu 2 HD - Thor 2/3 (1.0W)",
#                         "url": "https://www.mtvuutiset.fi/tvopas#/wide",
#                         "country": "Finland",
#                         "country_code": "FIN"
#                     },
#                     {
#                         "name": "Digi Sport 2 RO - Thor 2/3 (1.0W)",
#                         "url": "http://www.digisport.ro/Program/",
#                         "country": "Romania",
#                         "country_code": "ROU"
#                     },
#                     {
#                         "name": "TNT Sports 2 - Eurobird 1 / Astra 2A/2B/2D (28.2E)",
#                         "url": "https://player.ee.co.uk/#/livetv/schedule?filter=Sport",
#                         "country": "Great Britain",
#                         "country_code": "GBR"
#                     },
#                     {
#                         "name": "V Sport Live 2 HD - Thor 2/3 (1.0W)",
#                         "url": "https://www.allente.se/tv-guide/",
#                         "country": "Sweden",
#                         "country_code": "SWE"
#                     },
#                     {
#                         "name": "Novasports Prime HD - Hot Bird 1/2/3/4/6 (13.0E)",
#                         "url": "https://www.gazzetta.gr/tv-program",
#                         "country": "Greece",
#                         "country_code": "GRC"
#                     },
#                     {
#                         "name": "Sky Austria 3 HD - Astra 1C-1H / 2C (19.2E)",
#                         "url": "https://info.sky.de/inhalt/de/programm_info_live_events_start.jsp",
#                         "country": "Austria",
#                         "country_code": "AUT"
#                     },
#                     {
#                         "name": "Paramount+",
#                         "url": "https://worldsoccertalk.com/serie-a-tv-schedule/",
#                         "country": "United States",
#                         "country_code": "USA"
#                     },
#                     {
#                         "name": "ViX+",
#                         "country": "United States",
#                         "country_code": "USA"
#                     },
#                     {
#                         "name": "CANAL+ Foot FR - Astra 1C-1H / 2C (19.2E)",
#                         "url": "https://www.canalplus.com/programme-tv/",
#                         "country": "France",
#                         "country_code": "FRA"
#                     }
#                 ],
#                 "sport_event_conditions": {
#                     "referees": [
#                         {
#                             "id": "sr:referee:300916",
#                             "name": "Obrenovic, Rade",
#                             "nationality": "Slovenia",
#                             "country_code": "SVN",
#                             "type": "main_referee"
#                         },
#                         {
#                             "id": "sr:referee:130339",
#                             "name": "Praprotnik, Jure",
#                             "nationality": "Slovenia",
#                             "country_code": "SVN",
#                             "type": "first_assistant_referee"
#                         },
#                         {
#                             "id": "sr:referee:323271",
#                             "name": "Kordez, Grega",
#                             "nationality": "Slovenia",
#                             "country_code": "SVN",
#                             "type": "second_assistant_referee"
#                         },
#                         {
#                             "id": "sr:referee:755880",
#                             "name": "Smajc, David",
#                             "nationality": "Slovenia",
#                             "country_code": "SVN",
#                             "type": "fourth_official"
#                         },
#                         {
#                             "id": "sr:referee:178539",
#                             "name": "Borosak, Alen",
#                             "nationality": "Slovenia",
#                             "country_code": "SVN",
#                             "type": "video_assistant_referee"
#                         }
#                     ],
#                     "attendance": {
#                         "count": 59410
#                     },
#                     "weather": {
#                         "pitch_conditions": "good",
#                         "overall_conditions": "medium"
#                     },
#                     "ground": {
#                         "neutral": false
#                     },
#                     "lineups": {
#                         "confirmed": true
#                     }
#                 }
#             },
#             "sport_event_status": {
#                 "status": "closed",
#                 "match_status": "ended",
#                 "home_score": 2,
#                 "away_score": 2,
#                 "period_scores": [
#                     {
#                         "home_score": 2,
#                         "away_score": 1,
#                         "type": "regular_period",
#                         "number": 1
#                     },
#                     {
#                         "home_score": 0,
#                         "away_score": 1,
#                         "type": "regular_period",
#                         "number": 2
#                     }
#                 ],
#                 "ball_locations": [
#                     {
#                         "order": 4,
#                         "x": 5,
#                         "y": 50,
#                         "qualifier": "home"
#                     },
#                     {
#                         "order": 3,
#                         "x": 9,
#                         "y": 54,
#                         "qualifier": "away"
#                     },
#                     {
#                         "order": 2,
#                         "x": 37,
#                         "y": 52,
#                         "qualifier": "away"
#                     },
#                     {
#                         "order": 1,
#                         "x": 35,
#                         "y": 8,
#                         "qualifier": "away"
#                     }
#                 ],
#                 "match_situation": {
#                     "status": "safe",
#                     "qualifier": "home",
#                     "updated_at": "2025-03-12T21:51:28+00:00"
#                 }
#             }
#         },
#         {
#             "sport_event": {
#                 "id": "sr:sport_event:50850525",
#                 "start_time": "2025-03-09T16:30:00+00:00",
#                 "start_time_confirmed": true,
#                 "sport_event_context": {
#                     "sport": {
#                         "id": "sr:sport:1",
#                         "name": "Soccer"
#                     },
#                     "category": {
#                         "id": "sr:category:1",
#                         "name": "England",
#                         "country_code": "ENG"
#                     },
#                     "competition": {
#                         "id": "sr:competition:17",
#                         "name": "Premier League",
#                         "gender": "men"
#                     },
#                     "season": {
#                         "id": "sr:season:118689",
#                         "name": "Premier League 24/25",
#                         "start_date": "2024-08-16",
#                         "end_date": "2025-05-25",
#                         "year": "24/25",
#                         "competition_id": "sr:competition:17"
#                     },
#                     "stage": {
#                         "order": 1,
#                         "type": "league",
#                         "phase": "regular season",
#                         "start_date": "2024-08-16",
#                         "end_date": "2025-05-25",
#                         "year": "24/25"
#                     },
#                     "round": {
#                         "number": 28
#                     },
#                     "groups": [
#                         {
#                             "id": "sr:league:84075",
#                             "name": "Premier League 24/25"
#                         }
#                     ]
#                 },
#                 "coverage": {
#                     "type": "sport_event",
#                     "sport_event_properties": {
#                         "lineups": true,
#                         "formations": false,
#                         "venue": true,
#                         "extended_player_stats": true,
#                         "extended_team_stats": true,
#                         "lineups_availability": "pre",
#                         "ballspotting": true,
#                         "commentary": true,
#                         "fun_facts": true,
#                         "goal_scorers": true,
#                         "goal_scorers_live": true,
#                         "scores": "live",
#                         "game_clock": true,
#                         "deeper_play_by_play": true,
#                         "deeper_player_stats": true,
#                         "deeper_team_stats": true,
#                         "basic_play_by_play": true,
#                         "basic_player_stats": true,
#                         "basic_team_stats": true
#                     }
#                 },
#                 "competitors": [
#                     {
#                         "id": "sr:competitor:35",
#                         "name": "Manchester United",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "MUN",
#                         "qualifier": "home",
#                         "gender": "male"
#                     },
#                     {
#                         "id": "sr:competitor:42",
#                         "name": "Arsenal FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "ARS",
#                         "qualifier": "away",
#                         "gender": "male"
#                     }
#                 ],
#                 "venue": {
#                     "id": "sr:venue:9",
#                     "name": "Old Trafford",
#                     "capacity": 75635,
#                     "city_name": "Manchester",
#                     "country_name": "England",
#                     "map_coordinates": "53.463150,-2.291444",
#                     "country_code": "ENG",
#                     "timezone": "Europe/London"
#                 },
#                 "channels": [
#                     {
#                         "name": "Sky Sports Main Event HD - Astra 2A/2B/2D (28.2E)",
#                         "url": "http://www.skysports.com/watch/sport-on-sky",
#                         "country": "Great Britain",
#                         "country_code": "GBR"
#                     },
#                     {
#                         "name": "Bein Sports HD 3 TR - T\u00fcrksat 1C / Eurasiasat 1 (42.0E)",
#                         "url": "http://tr.beinsports.com/yayin-akisi/beinsports-3",
#                         "country": "Turkey",
#                         "country_code": "TUR"
#                     },
#                     {
#                         "name": "CANAL+ FR - Astra 1C-1H / 2C (19.2E)",
#                         "url": "https://www.canalplus.com/programme-tv/",
#                         "country": "France",
#                         "country_code": "FRA"
#                     },
#                     {
#                         "name": "Digi Sport 2 RO - Thor 2/3 (1.0W)",
#                         "url": "http://www.digisport.ro/Program/",
#                         "country": "Romania",
#                         "country_code": "ROU"
#                     },
#                     {
#                         "name": "Sky Sports PL HD - Astra 2A/2B/2D (28.2E)",
#                         "url": "http://www.skysports.com/watch/sport-on-sky",
#                         "country": "Great Britain",
#                         "country_code": "GBR"
#                     },
#                     {
#                         "name": "V Sport Premium HD - Thor 2/3 (1.0W)",
#                         "url": "https://www.allente.se/tv-guide/",
#                         "country": "Sweden",
#                         "country_code": "SWE"
#                     },
#                     {
#                         "name": "Spiler 1 TV - Thor 2/3 (1.0W)",
#                         "url": "http://spilertv.hu/musorujsag/",
#                         "country": "Hungary",
#                         "country_code": "HUN"
#                     },
#                     {
#                         "name": "Spiler 1 TV - Thor 2/3 (1.0W)",
#                         "url": "http://spilertv.hu/musorujsag/",
#                         "country": "Romania",
#                         "country_code": "ROU"
#                     },
#                     {
#                         "name": "NBC (DirecTV SAT (DVB-S))",
#                         "country": "United States",
#                         "country_code": "USA"
#                     },
#                     {
#                         "name": "Telemundo",
#                         "country": "United States",
#                         "country_code": "USA"
#                     },
#                     {
#                         "name": "Peacock Premium",
#                         "country": "United States",
#                         "country_code": "USA"
#                     },
#                     {
#                         "name": "Fubo TV",
#                         "url": "https://www.livesoccertv.com/channels/fubo-tv/",
#                         "country": "United States",
#                         "country_code": "USA"
#                     },
#                     {
#                         "name": "Sky Sport Top Event HD - Astra 1C-1H / 2C (19.2E)",
#                         "url": "https://info.sky.de/inhalt/de/programm_info_live_events_start.jsp",
#                         "country": "Germany",
#                         "country_code": "DEU"
#                     },
#                     {
#                         "name": "Sky Sport Premier League HD - Astra 1C-1H / 2C (19.2E)",
#                         "url": "https://info.sky.de/inhalt/de/programm_info_live_events_start.jsp",
#                         "country": "Germany",
#                         "country_code": "DEU"
#                     },
#                     {
#                         "name": "Sky Sport Max HD - Hot Bird 1/2/3/4/6 (13.0E)",
#                         "url": "https://guidatv.sky.it/sport-e-calcio?vista=griglia",
#                         "country": "Italy",
#                         "country_code": "ITA"
#                     }
#                 ],
#                 "sport_event_conditions": {
#                     "referees": [
#                         {
#                             "id": "sr:referee:69853",
#                             "name": "Taylor, Anthony",
#                             "nationality": "England",
#                             "country_code": "ENG",
#                             "type": "main_referee"
#                         },
#                         {
#                             "id": "sr:referee:79054",
#                             "name": "Beswick, Gary",
#                             "nationality": "England",
#                             "country_code": "ENG",
#                             "type": "first_assistant_referee"
#                         },
#                         {
#                             "id": "sr:referee:102306",
#                             "name": "Nunn, Adam",
#                             "nationality": "England",
#                             "country_code": "ENG",
#                             "type": "second_assistant_referee"
#                         },
#                         {
#                             "id": "sr:referee:79925",
#                             "name": "Bond, Darren",
#                             "nationality": "England",
#                             "country_code": "ENG",
#                             "type": "fourth_official"
#                         },
#                         {
#                             "id": "sr:referee:104864",
#                             "name": "Tierney, Paul",
#                             "nationality": "England",
#                             "country_code": "ENG",
#                             "type": "video_assistant_referee"
#                         }
#                     ],
#                     "attendance": {
#                         "count": 73812
#                     },
#                     "weather": {
#                         "pitch_conditions": "good",
#                         "overall_conditions": "good"
#                     },
#                     "ground": {
#                         "neutral": false
#                     },
#                     "lineups": {
#                         "confirmed": true
#                     }
#                 }
#             },
#             "sport_event_status": {
#                 "status": "closed",
#                 "match_status": "ended",
#                 "home_score": 1,
#                 "away_score": 1,
#                 "period_scores": [
#                     {
#                         "home_score": 1,
#                         "away_score": 0,
#                         "type": "regular_period",
#                         "number": 1
#                     },
#                     {
#                         "home_score": 0,
#                         "away_score": 1,
#                         "type": "regular_period",
#                         "number": 2
#                     }
#                 ],
#                 "match_tie": true,
#                 "ball_locations": [
#                     {
#                         "order": 4,
#                         "x": 10,
#                         "y": 53,
#                         "qualifier": "away"
#                     },
#                     {
#                         "order": 3,
#                         "x": 8,
#                         "y": 45,
#                         "qualifier": "away"
#                     },
#                     {
#                         "order": 2,
#                         "x": 10,
#                         "y": 85,
#                         "qualifier": "away"
#                     },
#                     {
#                         "order": 1,
#                         "x": 31,
#                         "y": 81,
#                         "qualifier": "away"
#                     }
#                 ],
#                 "match_situation": {
#                     "status": "dangerous",
#                     "qualifier": "away",
#                     "updated_at": "2025-03-09T18:25:42+00:00"
#                 }
#             }
#         },
#         {
#             "sport_event": {
#                 "id": "sr:sport_event:58261999",
#                 "start_time": "2025-03-04T20:00:00+00:00",
#                 "start_time_confirmed": true,
#                 "sport_event_context": {
#                     "sport": {
#                         "id": "sr:sport:1",
#                         "name": "Soccer"
#                     },
#                     "category": {
#                         "id": "sr:category:393",
#                         "name": "International Clubs"
#                     },
#                     "competition": {
#                         "id": "sr:competition:7",
#                         "name": "UEFA Champions League",
#                         "gender": "men"
#                     },
#                     "season": {
#                         "id": "sr:season:119239",
#                         "name": "UEFA Champions League 24/25",
#                         "start_date": "2024-07-09",
#                         "end_date": "2025-05-31",
#                         "year": "24/25",
#                         "competition_id": "sr:competition:7"
#                     },
#                     "stage": {
#                         "order": 4,
#                         "type": "cup",
#                         "phase": "playoffs",
#                         "start_date": "2025-02-11",
#                         "end_date": "2025-05-31",
#                         "year": "24/25"
#                     },
#                     "round": {
#                         "name": "round_of_16",
#                         "other_sport_event_id": "sr:sport_event:58261997",
#                         "cup_round_sport_event_number": 1,
#                         "cup_round_number_of_sport_events": 2,
#                         "cup_round_id": "sr:cup_round:2319081"
#                     },
#                     "groups": [
#                         {
#                             "id": "sr:cup:166619",
#                             "name": "UEFA Champions League 24/25, Knockout stage"
#                         }
#                     ]
#                 },
#                 "coverage": {
#                     "type": "sport_event",
#                     "sport_event_properties": {
#                         "lineups": true,
#                         "formations": false,
#                         "venue": true,
#                         "extended_player_stats": true,
#                         "extended_team_stats": true,
#                         "lineups_availability": "pre",
#                         "ballspotting": true,
#                         "commentary": true,
#                         "fun_facts": true,
#                         "goal_scorers": true,
#                         "goal_scorers_live": true,
#                         "scores": "live",
#                         "game_clock": true,
#                         "deeper_play_by_play": true,
#                         "deeper_player_stats": true,
#                         "deeper_team_stats": true,
#                         "basic_play_by_play": true,
#                         "basic_player_stats": true,
#                         "basic_team_stats": true
#                     }
#                 },
#                 "competitors": [
#                     {
#                         "id": "sr:competitor:2952",
#                         "name": "PSV Eindhoven",
#                         "country": "Netherlands",
#                         "country_code": "NLD",
#                         "abbreviation": "PSV",
#                         "qualifier": "home",
#                         "gender": "male"
#                     },
#                     {
#                         "id": "sr:competitor:42",
#                         "name": "Arsenal FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "ARS",
#                         "qualifier": "away",
#                         "gender": "male"
#                     }
#                 ],
#                 "venue": {
#                     "id": "sr:venue:726",
#                     "name": "Philips Stadion",
#                     "capacity": 35000,
#                     "city_name": "Eindhoven",
#                     "country_name": "Netherlands",
#                     "map_coordinates": "51.441781,5.467442",
#                     "country_code": "NLD",
#                     "timezone": "Europe/Brussels"
#                 },
#                 "channels": [
#                     {
#                         "name": "Canal+ Live 3 HD FR - Astra 1C-1H / 2C (19.2E)",
#                         "url": "https://www.footao.tv/",
#                         "country": "France",
#                         "country_code": "FRA"
#                     },
#                     {
#                         "name": "Sky Sport Calcio HD - Hot Bird 1/2/3/4/6 (13.0E)",
#                         "url": "https://www.goal.com/it/notizie/guida-tv-dove-vedere-tutto-il-calcio-in-diretta-e-streaming/1674frahvw8qt1nojf0cwjwlzr",
#                         "country": "Italy",
#                         "country_code": "ITA"
#                     },
#                     {
#                         "name": "SKY Sport 253 HD - Hot Bird 1/2/3/4/6 (13.0E)",
#                         "url": "https://guidatv.sky.it/sport-e-calcio?vista=griglia",
#                         "country": "Italy",
#                         "country_code": "ITA"
#                     },
#                     {
#                         "name": "MTV Urheilu 2 HD - Thor 2/3 (1.0W)",
#                         "url": "https://www.mtvuutiset.fi/tvopas#/wide",
#                         "country": "Finland",
#                         "country_code": "FIN"
#                     },
#                     {
#                         "name": "Digi Sport 2 RO - Thor 2/3 (1.0W)",
#                         "url": "http://www.digisport.ro/Program/",
#                         "country": "Romania",
#                         "country_code": "ROU"
#                     },
#                     {
#                         "name": "Sky Austria 4 HD - Astra 1C-1H / 2C (19.2E)",
#                         "url": "https://info.sky.de/inhalt/de/programm_info_live_events_start.jsp",
#                         "country": "Austria",
#                         "country_code": "AUT"
#                     },
#                     {
#                         "name": "Paramount+",
#                         "url": "https://worldsoccertalk.com/serie-a-tv-schedule/",
#                         "country": "United States",
#                         "country_code": "USA"
#                     },
#                     {
#                         "name": "ViX+",
#                         "country": "United States",
# ...
#                         "qualifier": "away",
#                         "gender": "male"
#                     }
#                 ],
#                 "venue": {
#                     "id": "sr:venue:624",
#                     "name": "Emirates Stadium",
#                     "capacity": 60704,
#                     "city_name": "London",
#                     "country_name": "England",
#                     "map_coordinates": "51.555050,-0.108046",
#                     "country_code": "ENG",
#                     "timezone": "Europe/London"
#                 },
#                 "sport_event_conditions": {
#                     "ground": {
#                         "neutral": false
#                     }
#                 }
#             },
#             "sport_event_status": {
#                 "status": "not_started",
#                 "match_status": "not_started"
#             }
#         },
#         {
#             "sport_event": {
#                 "id": "sr:sport_event:58265369",
#                 "start_time": "2025-04-08T19:00:00+00:00",
#                 "start_time_confirmed": true,
#                 "sport_event_context": {
#                     "sport": {
#                         "id": "sr:sport:1",
#                         "name": "Soccer"
#                     },
#                     "category": {
#                         "id": "sr:category:393",
#                         "name": "International Clubs"
#                     },
#                     "competition": {
#                         "id": "sr:competition:7",
#                         "name": "UEFA Champions League",
#                         "gender": "men"
#                     },
#                     "season": {
#                         "id": "sr:season:119239",
#                         "name": "UEFA Champions League 24/25",
#                         "start_date": "2024-07-09",
#                         "end_date": "2025-05-31",
#                         "year": "24/25",
#                         "competition_id": "sr:competition:7"
#                     },
#                     "stage": {
#                         "order": 4,
#                         "type": "cup",
#                         "phase": "playoffs",
#                         "start_date": "2025-02-11",
#                         "end_date": "2025-05-31",
#                         "year": "24/25"
#                     },
#                     "round": {
#                         "name": "quarterfinal",
#                         "other_sport_event_id": "sr:sport_event:58265377",
#                         "cup_round_sport_event_number": 1,
#                         "cup_round_number_of_sport_events": 2,
#                         "cup_round_id": "sr:cup_round:2319135"
#                     },
#                     "groups": [
#                         {
#                             "id": "sr:cup:166619",
#                             "name": "UEFA Champions League 24/25, Knockout stage"
#                         }
#                     ]
#                 },
#                 "coverage": {
#                     "type": "sport_event",
#                     "sport_event_properties": {
#                         "lineups": true,
#                         "formations": false,
#                         "venue": true,
#                         "extended_player_stats": true,
#                         "extended_team_stats": true,
#                         "lineups_availability": "pre",
#                         "ballspotting": true,
#                         "commentary": true,
#                         "fun_facts": true,
#                         "goal_scorers": true,
#                         "goal_scorers_live": true,
#                         "scores": "live",
#                         "game_clock": true,
#                         "deeper_play_by_play": true,
#                         "deeper_player_stats": true,
#                         "deeper_team_stats": true,
#                         "basic_play_by_play": true,
#                         "basic_player_stats": true,
#                         "basic_team_stats": true
#                     }
#                 },
#                 "competitors": [
#                     {
#                         "id": "sr:competitor:42",
#                         "name": "Arsenal FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "ARS",
#                         "qualifier": "home",
#                         "gender": "male"
#                     },
#                     {
#                         "id": "sr:competitor:2829",
#                         "name": "Real Madrid",
#                         "country": "Spain",
#                         "country_code": "ESP",
#                         "abbreviation": "RMA",
#                         "qualifier": "away",
#                         "gender": "male"
#                     }
#                 ],
#                 "venue": {
#                     "id": "sr:venue:624",
#                     "name": "Emirates Stadium",
#                     "capacity": 60704,
#                     "city_name": "London",
#                     "country_name": "England",
#                     "map_coordinates": "51.555050,-0.108046",
#                     "country_code": "ENG",
#                     "timezone": "Europe/London"
#                 },
#                 "channels": [
#                     {
#                         "name": "Paramount+",
#                         "url": "https://worldsoccertalk.com/serie-a-tv-schedule/",
#                         "country": "United States",
#                         "country_code": "USA"
#                     },
#                     {
#                         "name": "ViX+",
#                         "country": "United States",
#                         "country_code": "USA"
#                     }
#                 ],
#                 "sport_event_conditions": {
#                     "ground": {
#                         "neutral": false
#                     }
#                 }
#             },
#             "sport_event_status": {
#                 "status": "not_started",
#                 "match_status": "not_started"
#             }
#         },
#         {
#             "sport_event": {
#                 "id": "sr:sport_event:50850581",
#                 "start_time": "2025-04-05T11:30:00+00:00",
#                 "start_time_confirmed": true,
#                 "sport_event_context": {
#                     "sport": {
#                         "id": "sr:sport:1",
#                         "name": "Soccer"
#                     },
#                     "category": {
#                         "id": "sr:category:1",
#                         "name": "England",
#                         "country_code": "ENG"
#                     },
#                     "competition": {
#                         "id": "sr:competition:17",
#                         "name": "Premier League",
#                         "gender": "men"
#                     },
#                     "season": {
#                         "id": "sr:season:118689",
#                         "name": "Premier League 24/25",
#                         "start_date": "2024-08-16",
#                         "end_date": "2025-05-25",
#                         "year": "24/25",
#                         "competition_id": "sr:competition:17"
#                     },
#                     "stage": {
#                         "order": 1,
#                         "type": "league",
#                         "phase": "regular season",
#                         "start_date": "2024-08-16",
#                         "end_date": "2025-05-25",
#                         "year": "24/25"
#                     },
#                     "round": {
#                         "number": 31
#                     },
#                     "groups": [
#                         {
#                             "id": "sr:league:84075",
#                             "name": "Premier League 24/25"
#                         }
#                     ]
#                 },
#                 "coverage": {
#                     "type": "sport_event",
#                     "sport_event_properties": {
#                         "lineups": true,
#                         "formations": false,
#                         "venue": true,
#                         "extended_player_stats": true,
#                         "extended_team_stats": true,
#                         "lineups_availability": "pre",
#                         "ballspotting": true,
#                         "commentary": true,
#                         "fun_facts": true,
#                         "goal_scorers": true,
#                         "goal_scorers_live": true,
#                         "scores": "live",
#                         "game_clock": true,
#                         "deeper_play_by_play": true,
#                         "deeper_player_stats": true,
#                         "deeper_team_stats": true,
#                         "basic_play_by_play": true,
#                         "basic_player_stats": true,
#                         "basic_team_stats": true
#                     }
#                 },
#                 "competitors": [
#                     {
#                         "id": "sr:competitor:48",
#                         "name": "Everton FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "EVE",
#                         "qualifier": "home",
#                         "gender": "male"
#                     },
#                     {
#                         "id": "sr:competitor:42",
#                         "name": "Arsenal FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "ARS",
#                         "qualifier": "away",
#                         "gender": "male"
#                     }
#                 ],
#                 "venue": {
#                     "id": "sr:venue:12",
#                     "name": "Goodison Park",
#                     "capacity": 39572,
#                     "city_name": "Liverpool",
#                     "country_name": "England",
#                     "map_coordinates": "53.439255,-2.967065",
#                     "country_code": "ENG",
#                     "timezone": "Europe/London"
#                 },
#                 "sport_event_conditions": {
#                     "ground": {
#                         "neutral": false
#                     }
#                 }
#             },
#             "sport_event_status": {
#                 "status": "not_started",
#                 "match_status": "not_started"
#             }
#         },
#         {
#             "sport_event": {
#                 "id": "sr:sport_event:50850557",
#                 "start_time": "2025-04-01T18:45:00+00:00",
#                 "start_time_confirmed": true,
#                 "sport_event_context": {
#                     "sport": {
#                         "id": "sr:sport:1",
#                         "name": "Soccer"
#                     },
#                     "category": {
#                         "id": "sr:category:1",
#                         "name": "England",
#                         "country_code": "ENG"
#                     },
#                     "competition": {
#                         "id": "sr:competition:17",
#                         "name": "Premier League",
#                         "gender": "men"
#                     },
#                     "season": {
#                         "id": "sr:season:118689",
#                         "name": "Premier League 24/25",
#                         "start_date": "2024-08-16",
#                         "end_date": "2025-05-25",
#                         "year": "24/25",
#                         "competition_id": "sr:competition:17"
#                     },
#                     "stage": {
#                         "order": 1,
#                         "type": "league",
#                         "phase": "regular season",
#                         "start_date": "2024-08-16",
#                         "end_date": "2025-05-25",
#                         "year": "24/25"
#                     },
#                     "round": {
#                         "number": 30
#                     },
#                     "groups": [
#                         {
#                             "id": "sr:league:84075",
#                             "name": "Premier League 24/25"
#                         }
#                     ]
#                 },
#                 "coverage": {
#                     "type": "sport_event",
#                     "sport_event_properties": {
#                         "lineups": true,
#                         "formations": false,
#                         "venue": true,
#                         "extended_player_stats": true,
#                         "extended_team_stats": true,
#                         "lineups_availability": "pre",
#                         "ballspotting": true,
#                         "commentary": true,
#                         "fun_facts": true,
#                         "goal_scorers": true,
#                         "goal_scorers_live": true,
#                         "scores": "live",
#                         "game_clock": true,
#                         "deeper_play_by_play": true,
#                         "deeper_player_stats": true,
#                         "deeper_team_stats": true,
#                         "basic_play_by_play": true,
#                         "basic_player_stats": true,
#                         "basic_team_stats": true
#                     }
#                 },
#                 "competitors": [
#                     {
#                         "id": "sr:competitor:42",
#                         "name": "Arsenal FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "ARS",
#                         "qualifier": "home",
#                         "gender": "male"
#                     },
#                     {
#                         "id": "sr:competitor:43",
#                         "name": "Fulham FC",
#                         "country": "England",
#                         "country_code": "ENG",
#                         "abbreviation": "FUL",
#                         "qualifier": "away",
#                         "gender": "male"
#                     }
#                 ],
#                 "venue": {
#                     "id": "sr:venue:624",
#                     "name": "Emirates Stadium",
#                     "capacity": 60704,
#                     "city_name": "London",
#                     "country_name": "England",
#                     "map_coordinates": "51.555050,-0.108046",
#                     "country_code": "ENG",
#                     "timezone": "Europe/London"
#                 },
#                 "channels": [
#                     {
#                         "name": "Digi Sport 3 RO - Thor 2/3 (1.0W)",
#                         "url": "http://www.digisport.ro/Program/",
#                         "country": "Romania",
#                         "country_code": "ROU"
#                     },
#                     {
#                         "name": "V Sport Premium HD - Thor 2/3 (1.0W)",
#                         "url": "https://www.allente.se/tv-guide/",
#                         "country": "Sweden",
#                         "country_code": "SWE"
#                     },
#                     {
#                         "name": "Peacock Premium",
#                         "country": "United States",
#                         "country_code": "USA"
#                     }
#                 ],
#                 "sport_event_conditions": {
#                     "ground": {
#                         "neutral": false
#                     }
#                 }
#             },
#             "sport_event_status": {
#                 "status": "not_started",
#                 "match_status": "not_started"
#             }
#         }
#     ]
# }
# ✅ Arsenal Matches (41 games):
#   - 2025-03-16T13:30:00+00:00 | Arsenal FC vs Chelsea FC
#   - 2025-03-12T20:00:00+00:00 | Arsenal FC vs PSV Eindhoven
#   - 2025-03-09T16:30:00+00:00 | Manchester United vs Arsenal FC
#   - 2025-03-04T20:00:00+00:00 | PSV Eindhoven vs Arsenal FC
#   - 2025-02-26T19:30:00+00:00 | Nottingham Forest vs Arsenal FC
#
# 🔄 Fetching Arsenal statistics...
# ✅ Arsenal Stats Retrieved Successfully
